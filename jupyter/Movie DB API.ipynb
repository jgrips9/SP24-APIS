# %%
# !pip install pandas
# !pip install requests
import pandas as pd
import requests
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)

# %%
#Extract top rated movies from themoviedv. Link below is where we extract this from
#https://www.themoviedb.org/movie/top-rated
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=e8f47b23e6250bc0d8cb662b80682a91&language=en-US&page=1').json()

# %%
#This is the format of 'json' data. How we will pull
print(response)
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 146.944, 'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.711, 'vote_count': 25381}, {'adult': False, 'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg', 'genre_ids': [18, 80], 'id': 238, 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.', 'popularity': 121.87, 'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg', 'release_date': '1972-03-14', 'title': 'The Godfather', 'video': False, 'vote_average': 8.707, 'vote_count': 19325}, {'adult': False, 'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg', 'genre_ids': [18, 80], 'id': 240, 'original_language': 'en', 'original_title': 'The Godfather Part II', 'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.', 'popularity': 82.27, 'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg', 'release_date': '1974-12-20', 'title': 'The Godfather Part II', 'video': False, 'vote_average': 8.592, 'vote_count': 11660}, {'adult': False, 'backdrop_path': '/3f92DMBTFqr3wgXpfxzrb0qv8nG.jpg', 'genre_ids': [18, 36, 10752], 'id': 424, 'original_language': 'en', 'original_title': "Schindler's List", 'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.', 'popularity': 66.67, 'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg', 'release_date': '1993-12-15', 'title': "Schindler's List", 'video': False, 'vote_average': 8.6, 'vote_count': 15019}, {'adult': False, 'backdrop_path': '/qqHQsStV6exghCM7zbObuYBiYxw.jpg', 'genre_ids': [18], 'id': 389, 'original_language': 'en', 'original_title': '12 Angry Men', 'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.", 'popularity': 59.231, 'poster_path': '/ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg', 'release_date': '1957-04-10', 'title': '12 Angry Men', 'video': False, 'vote_average': 8.545, 'vote_count': 7963}, {'adult': False, 'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg', 'genre_ids': [35, 18, 10749], 'id': 19404, 'original_language': 'hi', 'original_title': 'दिलवाले दुल्हनिया ले जायेंगे', 'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.', 'popularity': 41.801, 'poster_path': '/lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg', ...

# %%
#Extracting results subsection
print(response['results'])
# Out:
# [{'adult': False, 'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 146.944, 'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.711, 'vote_count': 25381}, {'adult': False, 'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg', 'genre_ids': [18, 80], 'id': 238, 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.', 'popularity': 121.87, 'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg', 'release_date': '1972-03-14', 'title': 'The Godfather', 'video': False, 'vote_average': 8.707, 'vote_count': 19325}, {'adult': False, 'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg', 'genre_ids': [18, 80], 'id': 240, 'original_language': 'en', 'original_title': 'The Godfather Part II', 'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.', 'popularity': 82.27, 'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg', 'release_date': '1974-12-20', 'title': 'The Godfather Part II', 'video': False, 'vote_average': 8.592, 'vote_count': 11660}, {'adult': False, 'backdrop_path': '/3f92DMBTFqr3wgXpfxzrb0qv8nG.jpg', 'genre_ids': [18, 36, 10752], 'id': 424, 'original_language': 'en', 'original_title': "Schindler's List", 'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.', 'popularity': 66.67, 'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg', 'release_date': '1993-12-15', 'title': "Schindler's List", 'video': False, 'vote_average': 8.6, 'vote_count': 15019}, {'adult': False, 'backdrop_path': '/qqHQsStV6exghCM7zbObuYBiYxw.jpg', 'genre_ids': [18], 'id': 389, 'original_language': 'en', 'original_title': '12 Angry Men', 'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.", 'popularity': 59.231, 'poster_path': '/ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg', 'release_date': '1957-04-10', 'title': '12 Angry Men', 'video': False, 'vote_average': 8.545, 'vote_count': 7963}, {'adult': False, 'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg', 'genre_ids': [35, 18, 10749], 'id': 19404, 'original_language': 'hi', 'original_title': 'दिलवाले दुल्हनिया ले जायेंगे', 'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.', 'popularity': 41.801, 'poster_path': '/lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg', 'release_date': '1995- ...

# %%
#Take all data from 'results' subcategory. Place into pandas dataframe
data = pd.DataFrame(response['results'])

# %%
#Print the dataset
display(data)
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg          [18, 80]     278
# 1   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg          [18, 80]     238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /3f92DMBTFqr3wgXpfxzrb0qv8nG.jpg   [18, 36, 10752]     424
# 4   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 5   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 6   False  /mSDsSDwaP3E7dEfUPWy4J0djt4O.jpg   [16, 10751, 14]     129
# 7   False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  [18, 28, 80, 53]     155
# 8   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 9   False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      [14, 18, 80]     497
# 10  False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg   [10749, 16, 18]  372058
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# 12  False  /qdIMHd4sEfJSckfVJfKQvisL02a.jpg   [35, 18, 10749]      13
# 13  False  /9DeGfFIqjph5CBFVQrD6wv9S7rR.jpg      [12, 14, 28]     122
# 14  False  /eoCSp75lxatmIa6aGqfnzwtbttd.jpg              [37]     429
# 15  False  /sw7mordbZxgITU877yTpZCud90M.jpg          [18, 80]     769
# 16  False  /qvZ91FwMq6O47VViAr8vZNQz3WI.jpg          [28, 18]     346
# 17  False  /dlC0ed9Ugh3FzydnkBtV5lRXUu4.jpg   [16, 18, 10752]   12477
# 18  False  /gavyCu1UaTaTNPsVaGXT6pe5u24.jpg          [35, 18]     637
# 19  False  /zoVeIgKzGJzpdG6Gwnr7iOYfIMU.jpg       [18, 10749]   11216
#
#    original_language                                 original_title  \
# 0                 en                       The Shawshank Redemption
# 1                 en                                  The Godfather
# 2                 en                          The Godfather Part II
# 3                 en                               Schindler's List
# 4                 en                                   12 Angry Men
# 5                 hi                   दिलवाले दुल्हनिया ले जायेंगे
# 6                 ja                                       千と千尋の神隠し
# 7                 en                                The Dark Knight
# 8                 ko                                            기생충
# 9                 en                                 The Green Mile
# 10                ja                                          君の名は。
# 11                en                                   Pulp Fiction
# 12                en                                   Forrest Gump
# 13                en  The Lord of the Rings: The Return of the King
# 14                it                Il buono, il brutto, il cattivo
# 15                en                                     GoodFellas
# 16                ja                                           七人の侍
# 17                ja                                          火垂るの墓
# 18                it                                La vita è bella
# 19                it                          Nuovo Cinema Paradiso
#
#                                              overview  popularity  \
# 0   Framed in the 1940s for the double murder of h...     146.944
# 1   Spanning the years 1945 to 1955, a chronicle o...     121.870
# 2   In the continuing saga of the Corleone crime f...      82.270
# 3   The true story of how businessman Oskar Schind...      66.670
# 4   The defense and the prosecution have rested an...      59.231
# 5   Raj is a rich, carefree, happy-go-lucky second...      41.801
# 6   A young girl, Chihiro, becomes trapped in a st...     117.641
# 7   Batman raises the stakes in his war on crime. ...     114.110
# 8   All unemployed, Ki-taek's family takes peculia...      89.574
# 9   A supernatural tale set on death row in a Sout...      72.209
# 10  High schoolers Mitsuha and Taki are complete s...      93.853
# 11  A burger-loving hit man, his philosophical par...      77.959
# 12  A man with a low IQ has accomplished great thi...      79.305
# 13  Aragorn is revealed as the heir to the ancient...      99.569
# 14  While the Civil War rages on between the Union...      64.636
# 15  The true story of Henry Hill, a half-Irish, ha...      62.035
# 16  A samurai answers a village's request for prot...      40.311
# 17  In the final months of World War II, 14-year-o...       0.600
# 18  A touching story of an Italian book seller of ...      56.558
# 19  A filmmaker recalls his childhood, when he fel...      36.539
#
#                          poster_path release_date  \
# 0   /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg   1994-09-23
# 1   /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 2   /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20
# 3   /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15
# 4   /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10
# 5   /lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg   1995-10-20
# 6   /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20
# 7   /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-16
# 8   /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30
# 9   /8VG8fDNiy50H4FedGwdSVUPoaJe.jpg   1999-12-10
# 10  /q719jXXEzOoYaps6babgKnONONX.jpg   2016-08-26
# 11  /d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg   1994-09-10
# 12  /arw2vcBveWOVZr6pxd9XTd1TdQa.jpg   1994-06-23
# 13  /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg   2003-12-01
# 14  /bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg   1966-12-22
# 15  /aKuFiU82s5ISJpGZp7YkIr3kCUd.jpg   1990-09-12
# 16  /8OKmBV5BUFzmozIC3pPWKHy17kx.jpg   1954-04-26
# 17  /k9tv1rXZbOhH7eiCk378x61kNQ1.jpg   1988-04-15
# 18  /6tEJnof1DKWPnl5lzkjf0FVv7oB.jpg   1997-12-20
# 19  /8SRUfRUi6x4O68n0VCbDNRa6iGL.jpg   1988-11-17
#
#                                             title  video  vote_average  \
# 0                        The Shawshank Redemption  False         8.711
# 1                                   The Godfather  False         8.707
# 2                           The Godfather Part II  False         8.592
# 3                                Schindler's List  False         8.600
# 4                                    12 Angry Men  False         8.545
# 5                     Dilwale Dulhania Le Jayenge  False         8.544
# 6                                   Spirited Away  False         8.539
# 7                                 The Dark Knight  False         8.514
# 8                                        Parasite  False         8.512
# 9                                  The Green Mile  False         8.510
# 10                                     Your Name.  False         8.500
# 11                                   Pulp Fiction  False         8.489
# 12                                   Forrest Gump  False         8.500
# 13  The Lord of the Rings: The Return of the King  False         8.476
# 14                 The Good, the Bad and the Ugly  False         8.470
# 15                                     GoodFellas  False         8.500
# 16                                  Seven Samurai  False         8.459
# 17                         Grave of the Fireflies  False         8.456
# 18                              Life Is Beautiful  False         8.456
# 19                                Cinema Paradiso  False         8.449
#
#     vote_count
# 0        25381
# 1        19325
# 2        11660
# 3        15019
# 4         7963
# 5         4324
# 6        15406
# 7        31296
# 8        16971
# 9        16382
# 10       10687
# 11       26498
# 12       26036
# 13       22895
# 14        8020
# 15       12087
# 16        3366
# 17        5058
# 18       12510
# 19        4087

# %%
#Subset dataset. Select desired columns from above using pandas
target_pd = data[['original_title', 'popularity', 'overview']]

#Extracting specific fields from API json data.
title = []
popularity = []
overview = []

for item in response['results']:
  title.append(item['original_title'])
  popularity.append(item['popularity'])
  overview.append(item['overview'])

target_api = pd.DataFrame({
    'title': title,
    'popularity': popularity,
    'overview': overview
})

# %%
#Display datasets
display(target_pd)
# Out:
#                                    original_title  popularity  \
# 0                        The Shawshank Redemption     146.944
# 1                                   The Godfather     121.870
# 2                           The Godfather Part II      82.270
# 3                                Schindler's List      66.670
# 4                                    12 Angry Men      59.231
# 5                    दिलवाले दुल्हनिया ले जायेंगे      41.801
# 6                                        千と千尋の神隠し     117.641
# 7                                 The Dark Knight     114.110
# 8                                             기생충      89.574
# 9                                  The Green Mile      72.209
# 10                                          君の名は。      93.853
# 11                                   Pulp Fiction      77.959
# 12                                   Forrest Gump      79.305
# 13  The Lord of the Rings: The Return of the King      99.569
# 14                Il buono, il brutto, il cattivo      64.636
# 15                                     GoodFellas      62.035
# 16                                           七人の侍      40.311
# 17                                          火垂るの墓       0.600
# 18                                La vita è bella      56.558
# 19                          Nuovo Cinema Paradiso      36.539
#
#                                              overview
# 0   Framed in the 1940s for the double murder of h...
# 1   Spanning the years 1945 to 1955, a chronicle o...
# 2   In the continuing saga of the Corleone crime f...
# 3   The true story of how businessman Oskar Schind...
# 4   The defense and the prosecution have rested an...
# 5   Raj is a rich, carefree, happy-go-lucky second...
# 6   A young girl, Chihiro, becomes trapped in a st...
# 7   Batman raises the stakes in his war on crime. ...
# 8   All unemployed, Ki-taek's family takes peculia...
# 9   A supernatural tale set on death row in a Sout...
# 10  High schoolers Mitsuha and Taki are complete s...
# 11  A burger-loving hit man, his philosophical par...
# 12  A man with a low IQ has accomplished great thi...
# 13  Aragorn is revealed as the heir to the ancient...
# 14  While the Civil War rages on between the Union...
# 15  The true story of Henry Hill, a half-Irish, ha...
# 16  A samurai answers a village's request for prot...
# 17  In the final months of World War II, 14-year-o...
# 18  A touching story of an Italian book seller of ...
# 19  A filmmaker recalls his childhood, when he fel...

# %%
display(target_api)
# Out:
#                                             title  popularity  \
# 0                        The Shawshank Redemption     146.944
# 1                                   The Godfather     121.870
# 2                           The Godfather Part II      82.270
# 3                                Schindler's List      66.670
# 4                                    12 Angry Men      59.231
# 5                    दिलवाले दुल्हनिया ले जायेंगे      41.801
# 6                                        千と千尋の神隠し     117.641
# 7                                 The Dark Knight     114.110
# 8                                             기생충      89.574
# 9                                  The Green Mile      72.209
# 10                                          君の名は。      93.853
# 11                                   Pulp Fiction      77.959
# 12                                   Forrest Gump      79.305
# 13  The Lord of the Rings: The Return of the King      99.569
# 14                Il buono, il brutto, il cattivo      64.636
# 15                                     GoodFellas      62.035
# 16                                           七人の侍      40.311
# 17                                          火垂るの墓       0.600
# 18                                La vita è bella      56.558
# 19                          Nuovo Cinema Paradiso      36.539
#
#                                              overview
# 0   Framed in the 1940s for the double murder of h...
# 1   Spanning the years 1945 to 1955, a chronicle o...
# 2   In the continuing saga of the Corleone crime f...
# 3   The true story of how businessman Oskar Schind...
# 4   The defense and the prosecution have rested an...
# 5   Raj is a rich, carefree, happy-go-lucky second...
# 6   A young girl, Chihiro, becomes trapped in a st...
# 7   Batman raises the stakes in his war on crime. ...
# 8   All unemployed, Ki-taek's family takes peculia...
# 9   A supernatural tale set on death row in a Sout...
# 10  High schoolers Mitsuha and Taki are complete s...
# 11  A burger-loving hit man, his philosophical par...
# 12  A man with a low IQ has accomplished great thi...
# 13  Aragorn is revealed as the heir to the ancient...
# 14  While the Civil War rages on between the Union...
# 15  The true story of Henry Hill, a half-Irish, ha...
# 16  A samurai answers a village's request for prot...
# 17  In the final months of World War II, 14-year-o...
# 18  A touching story of an Italian book seller of ...
# 19  A filmmaker recalls his childhood, when he fel...

# %%
#Go to following page and extract that information. Append to dataset.
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=e8f47b23e6250bc0d8cb662b80682a91&language=en-US&page=2').json()
data = pd.DataFrame(response['results'])
display(data)
# Out:
#     adult                     backdrop_path          genre_ids      id  \
# 0   False  /hZkgoQYus5vegHoetLkCJzb17zJ.jpg               [18]     550
# 1   False  /ySaK6hpbCc2OE13ac7ovhgWwR5u.jpg            [10402]  568332
# 2   False  /uvitbjFU4JqvMwIkMWHp69bmUzG.jpg           [18, 80]     598
# 3   False  /uif5fUshJrXyyDzfpzp1DLw3N0S.jpg     [27, 53, 9648]     539
# 4   False  /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg        [10749, 18]  696374
# 5   False  /bxSBOAD8AuMHYMdW3jso9npAkgt.jpg        [10751, 18]  667257
# 6   False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg      [12, 18, 878]  157336
# 7   False  /uPYa165sraN2c8gZBM9C47g3JoU.jpg           [18, 80]     311
# 8   False  /oje9d0EXQyQcxsqHQor4xFVGjrd.jpg               [18]     510
# 9   False  /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg        [10749, 18]  724089
# 10  False  /aVFx1VtlOxR3v0ADEatalXOvwbu.jpg       [16, 14, 28]  620249
# 11  False  /3RMLbSEXOn1CzLoNT7xFeLfdxhq.jpg        [10749, 16]  372754
# 12  False  /x2RS3uTcsJJ9IfjNPcgDmukoEcQ.jpg       [12, 14, 28]     120
# 13  False  /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg        [10749, 18]  761053
# 14  False  /qGQf2OHIkoh89K8XeKQzhxczf96.jpg  [28, 12, 16, 878]  324857
# 15  False  /nv5wwZou159v5OC61i4ElR7OqyY.jpg       [14, 16, 12]    4935
# 16  False  /alQqTpmEkxSLgajfEYTsTH6nAKB.jpg       [35, 18, 14]   40096
# 17  False  /l5K9elugftlcyIHHm4nylvsn26X.jpg               [18]  255709
# 18  False  /aJCtkxLLzkk1pECehVjKHA2lBgw.jpg      [12, 28, 878]    1891
# 19  False  /nS4picOwj15APKzJeBCk6EBcMG5.jpg       [12, 14, 28]     121
#
#    original_language                                     original_title  \
# 0                 en                                         Fight Club
# 1                 en              Taylor Swift: Reputation Stadium Tour
# 2                 pt                                     Cidade de Deus
# 3                 en                                             Psycho
# 4                 en                                  Gabriel's Inferno
# 5                 es                                   Cosas imposibles
# 6                 en                                       Interstellar
# 7                 en                        Once Upon a Time in America
# 8                 en                    One Flew Over the Cuckoo's Nest
# 9                 en                         Gabriel's Inferno: Part II
# 10                zh                                              罗小黑战记
# 11                ja                                                同級生
# 12                en  The Lord of the Rings: The Fellowship of the Ring
# 13                en                        Gabriel's Inferno: Part III
# 14                en                  Spider-Man: Into the Spider-Verse
# 15                ja                                            ハウルの動く城
# 16                pt                              O Auto da Compadecida
# 17                ko                                                 소원
# 18                en                            The Empire Strikes Back
# 19                en              The Lord of the Rings: The Two Towers
#
#                                              overview  popularity  \
# 0   A ticking-time-bomb insomniac and a slippery s...     111.866
# 1   Taylor Swift takes the stage in Dallas for the...      18.141
# 2   In the slums of Rio, two kids' paths diverge a...      36.073
# 3   When larcenous real estate clerk Marion Crane ...      42.139
# 4   An intriguing and sinful exploration of seduct...       9.295
# 5   Matilde is a woman who, after the death of her...      11.127
# 6   The adventures of a group of explorers who mak...     168.802
# 7   A former Prohibition-era Jewish gangster retur...      46.019
# 8   A petty criminal fakes insanity to serve his s...      48.203
# 9   Professor Gabriel Emerson finally learns the t...      10.187
# 10  When cat spirit Luo Xiaohei's home is deforest...      15.910
# 11  Rihito Sajo, an honor student with a perfect s...      13.830
# 12  Young hobbit Frodo Baggins, after inheriting a...     120.440
# 13  The final part of the film adaption of the ero...      17.930
# 14  Struggling to find his place in the world whil...     153.037
# 15  Sophie, a young milliner, is turned into an el...     107.626
# 16  The lively João Grilo and the sly Chicó are po...       9.960
# 17  After 8-year-old So-won narrowly survives a br...      17.659
# 18  The epic saga continues as Luke Skywalker, in ...      52.611
# 19  Frodo and Sam are trekking to Mordor to destro...     101.119
#
#                          poster_path release_date  \
# 0   /pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg   1999-10-15
# 1   /u6oXUTtOuJRPdUgUuPAVVJPSKCo.jpg   2018-12-31
# 2   /k7eYdWvhYQyRQoU2TB2A2Xu2TfD.jpg   2002-08-30
# 3   /yz4QVqPx3h1hD1DfqqQkCq3rmxW.jpg   1960-06-22
# 4   /oyG9TL7FcRP4EZ9Vid6uKzwdndz.jpg   2020-05-29
# 5   /t2Ew8NZ8Ci2kqmoecZUNQUFDJnQ.jpg   2021-06-17
# 6   /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg   2014-11-05
# 7   /i0enkzsL5dPeneWnjl1fCWm6L7k.jpg   1984-05-23
# 8   /3jcbDmRFiQ83drXNOvRDeKHxS0C.jpg   1975-11-19
# 9   /x5o8cLZfEXMoZczTYWLrUo1P7UJ.jpg   2020-07-31
# 10  /aLv87NgRJUPkQ6sVLP72IisDdt4.jpg   2019-08-27
# 11  /cIfRCA5wEvj9tApca4UDUagQEiM.jpg   2016-02-20
# 12  /6oom5QYQ2yQTMJIbnvbkBL9cHo6.jpg   2001-12-18
# 13  /fYtHxTxlhzD4QWfEbrC1rypysSD.jpg   2020-11-19
# 14  /iiZZdoQBEYBv6id8su7ImL0oCbD.jpg   2018-12-06
# 15  /6pZgH10jhpToPcf0uvyTCPFhWpI.jpg   2004-09-09
# 16  /imcOp1kJsCsAFCoOtY5OnPrFbAf.jpg   2000-09-15
# 17  /x9yjkm9gIz5qI5fJMUTfBnWiB2o.jpg   2013-10-02
# 18  /nNAeTmF4CtdSgMDplXTDPOpYzsX.jpg   1980-05-20
# 19  /5VTN0pR8gcqV3EPUHHfMGnJYN9L.jpg   2002-12-18
#
#                                                 title  video  vote_average  \
# 0                                          Fight Club  False         8.440
# 1               Taylor Swift: Reputation Stadium Tour  False         8.434
# 2                                         City of God  False         8.433
# 3                                              Psycho  False         8.433
# 4                                   Gabriel's Inferno  False         8.430
# 5                                   Impossible Things  False         8.430
# 6                                        Interstellar  False         8.426
# 7                         Once Upon a Time in America  False         8.423
# 8                     One Flew Over the Cuckoo's Nest  False         8.421
# 9                          Gabriel's Inferno: Part II  False         8.419
# 10                                  The Legend of Hei  False         8.419
# 11                           Dou kyu sei – Classmates  False         8.419
# 12  The Lord of the Rings: The Fellowship of the Ring  False         8.407
# 13                        Gabriel's Inferno: Part III  False         8.405
# 14                  Spider-Man: Into the Spider-Verse  False         8.405
# 15                               Howl's Moving Castle  False         8.405
# 16                                       A Dog's Will  False         8.400
# 17                                               Hope  False         8.394
# 18                            The Empire Strikes Back  False         8.391
# 19              The Lord of the Rings: The Two Towers  False         8.391
#
#     vote_count
# 0        27880
# 1          342
# 2         6890
# 3         9525
# 4         2385
# 5          365
# 6        33431
# 7         5035
# 8         9874
# 9         1491
# 10         320
# 11         335
# 12       23845
# 13        1036
# 14       14516
# 15        9073
# 16        1037
# 17         611
# 18       16110
# 19       20728

# %%
#Loop to go through multiple pages
#Go through 3 pages. 20 results per page.
page = 1
URL = 'https://api.themoviedb.org/3/movie/top_rated?api_key=e8f47b23e6250bc0d8cb662b80682a91&language=en-US&page='
#Create empty dataframe
title = []
popularity = []
overview = []

while page < 4:
  web_url = URL + str(page)
  response = requests.get(web_url).json()
  #Increment page
  page = page + 1
  for item in response['results']:
    title.append(item['original_title'])
    popularity.append(item['popularity'])
    overview.append(item['overview'])

target_api = pd.DataFrame({
    'title': title,
    'popularity': popularity,
    'overview': overview
})

# %%
display(target_api)
# Out:
#                                                 title  popularity  \
# 0                            The Shawshank Redemption     146.944
# 1                                       The Godfather     121.870
# 2                               The Godfather Part II      82.270
# 3                                    Schindler's List      66.670
# 4                                        12 Angry Men      59.231
# 5                        दिलवाले दुल्हनिया ले जायेंगे      41.801
# 6                                            千と千尋の神隠し     117.641
# 7                                     The Dark Knight     114.110
# 8                                                 기생충      89.574
# 9                                      The Green Mile      72.209
# 10                                              君の名は。      93.853
# 11                                       Pulp Fiction      77.959
# 12                                       Forrest Gump      79.305
# 13      The Lord of the Rings: The Return of the King      99.569
# 14                    Il buono, il brutto, il cattivo      64.636
# 15                                         GoodFellas      62.035
# 16                                               七人の侍      40.311
# 17                                              火垂るの墓       0.600
# 18                                    La vita è bella      56.558
# 19                              Nuovo Cinema Paradiso      36.539
# 20                                         Fight Club     111.866
# 21              Taylor Swift: Reputation Stadium Tour      18.141
# 22                                     Cidade de Deus      36.073
# 23                                             Psycho      42.139
# 24                                  Gabriel's Inferno       9.295
# 25                                   Cosas imposibles      11.127
# 26                                       Interstellar     168.802
# 27                        Once Upon a Time in America      46.019
# 28                    One Flew Over the Cuckoo's Nest      48.203
# 29                         Gabriel's Inferno: Part II      10.187
# 30                                              罗小黑战记      15.910
# 31                                                同級生      13.830
# 32  The Lord of the Rings: The Fellowship of the Ring     120.440
# 33                        Gabriel's Inferno: Part III      17.930
# 34                  Spider-Man: Into the Spider-Verse     153.037
# 35                                            ハウルの動く城     107.626
# 36                              O Auto da Compadecida       9.960
# 37                                                 소원      17.659
# 38                            The Empire Strikes Back      52.611
# 39              The Lord of the Rings: The Two Towers     101.119
# 40                                             映画 聲の形      54.820
# 41                                        The Pianist      44.753
# 42                                           Whiplash      64.886
# 43                                                 切腹      21.693
# 44                Spider-Man: Across the Spider-Verse     351.301
# 45                                          映画 五等分の花嫁      36.686
# 46                                              Se7en      68.891
# 47                                          Inception      99.533
# 48                                        Rear Window      28.809
# 49                                              蛍火の杜へ       0.600
# 50                                 American History X      27.259
# 51                           The Silence of the Lambs      12.694
# 52                                 The Great Dictator      23.356
# 53                                              もののけ姫      55.019
# 54                                  C'è ancora domani      39.690
# 55                                   Sunset Boulevard      23.970
# 56                                   Dedicada A Mi Ex       8.233
# 57           The Boy, the Mole, the Fox and the Horse      27.033
# 58                        新世紀エヴァンゲリオン劇場版 Air／まごころを、君に      40.072
# 59                                              天国と地獄      19.102
#
#                                              overview
# 0   Framed in the 1940s for the double murder of h...
# 1   Spanning the years 1945 to 1955, a chronicle o...
# 2   In the continuing saga of the Corleone crime f...
# 3   The true story of how businessman Oskar Schind...
# 4   The defense and the prosecution have rested an...
# 5   Raj is a rich, carefree, happy-go-lucky second...
# 6   A young girl, Chihiro, becomes trapped in a st...
# 7   Batman raises the stakes in his war on crime. ...
# 8   All unemployed, Ki-taek's family takes peculia...
# 9   A supernatural tale set on death row in a Sout...
# 10  High schoolers Mitsuha and Taki are complete s...
# 11  A burger-loving hit man, his philosophical par...
# 12  A man with a low IQ has accomplished great thi...
# 13  Aragorn is revealed as the heir to the ancient...
# 14  While the Civil War rages on between the Union...
# 15  The true story of Henry Hill, a half-Irish, ha...
# 16  A samurai answers a village's request for prot...
# 17  In the final months of World War II, 14-year-o...
# 18  A touching story of an Italian book seller of ...
# 19  A filmmaker recalls his childhood, when he fel...
# 20  A ticking-time-bomb insomniac and a slippery s...
# 21  Taylor Swift takes the stage in Dallas for the...
# 22  In the slums of Rio, two kids' paths diverge a...
# 23  When larcenous real estate clerk Marion Crane ...
# 24  An intriguing and sinful exploration of seduct...
# 25  Matilde is a woman who, after the death of her...
# 26  The adventures of a group of explorers who mak...
# 27  A former Prohibition-era Jewish gangster retur...
# 28  A petty criminal fakes insanity to serve his s...
# 29  Professor Gabriel Emerson finally learns the t...
# 30  When cat spirit Luo Xiaohei's home is deforest...
# 31  Rihito Sajo, an honor student with a perfect s...
# 32  Young hobbit Frodo Baggins, after inheriting a...
# 33  The final part of the film adaption of the ero...
# 34  Struggling to find his place in the world whil...
# 35  Sophie, a young milliner, is turned into an el...
# 36  The lively João Grilo and the sly Chicó are po...
# 37  After 8-year-old So-won narrowly survives a br...
# 38  The epic saga continues as Luke Skywalker, in ...
# 39  Frodo and Sam are trekking to Mordor to destro...
# 40  Shouya Ishida starts bullying the new girl in ...
# 41  The true story of pianist Władysław Szpilman's...
# 42  Under the direction of a ruthless instructor, ...
# 43  Down-on-his-luck veteran Tsugumo Hanshirō ente...
# 44  After reuniting with Gwen Stacy, Brooklyn’s fu...
# 45  When five lovely young girls who hate studying...
# 46  Two homicide detectives are on a desperate hun...
# 47  Cobb, a skilled thief who commits corporate es...
# 48  A wheelchair-bound photographer spies on his n...
# 49  One hot summer day a little girl gets lost in ...
# 50  Derek Vineyard is paroled after serving 3 year...
# 51  Clarice Starling is a top student at the FBI's...
# 52  Dictator Adenoid Hynkel tries to expand his em...
# 53  Ashitaka, a prince of the disappearing Emishi ...
# 54  Delia is a typical housewife in post-war Italy...
# 55  A hack screenwriter writes a screenplay for a ...
# 56  The film tells the story of Ariel, a 21-year-o...
# 57  The unlikely friendship of a boy, a mole, a fo...
# 58  The second of two theatrically released follow...
# 59  A shoe company executive who has mortgaged eve...

# %%
#Sources
#https://www.enjoyalgorithms.com/blog/api-introduction-for-data-science-and-ml
#https://www.themoviedb.org/movie/top-rated
