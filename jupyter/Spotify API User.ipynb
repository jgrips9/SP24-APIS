# %%
# !pip install spotipy
# !pip install pandas
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.0.7)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2023.11.17)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.1 spotipy-2.23.0
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd

# %%
#Go to this link to setup API
#https://developer.spotify.com/
#Input credential below.
cid = ''
secret = ''

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)

sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#Full documentation
#https://developer.spotify.com/documentation/web-api
#Album
#https://developer.spotify.com/documentation/web-api/reference/get-an-album
#Album tracks
#https://developer.spotify.com/documentation/web-api/reference/get-an-albums-tracks
#Artist albums
#https://developer.spotify.com/documentation/web-api/reference/get-an-artists-albums
#Artist top tracks
#https://developer.spotify.com/documentation/web-api/reference/get-an-artists-top-tracks
#Playlist
#https://developer.spotify.com/documentation/web-api/reference/get-playlist
#Playlist items
#https://developer.spotify.com/documentation/web-api/reference/get-playlists-tracks
#Tracks
#https://developer.spotify.com/documentation/web-api/reference/get-track
#Track audio features
#https://developer.spotify.com/documentation/web-api/reference/get-audio-features
#Audio analysis features
#https://developer.spotify.com/documentation/web-api/reference/get-audio-analysis

# %%
#This link is how to get to the playlist. Popular spotify songs tiktok 2024.
#https://open.spotify.com/playlist/6OcWuyMNKus06gmrh4FEiX?si=1333723a6eff4b7f&nd=1&dlsi=4522a9b2997c4cae
playlist = sp.user_playlist_tracks("spotify","6OcWuyMNKus06gmrh4FEiX")["items"]
#Store song id and name from playlist.
song = []
song_name = []
for track in playlist:
    song.append(track["track"]["id"])
    song_name.append(track["track"]["name"])

# %%
#Print song id
song[0]
# Out:
# '3rUGC1vUpkDG9CZFHMur1t'

# %%
#Store audio analysis results into an object.
test = sp.audio_analysis(song[0])
print(test)
# Out:
# {'meta': {'analyzer_version': '4.0.0', 'platform': 'Linux', 'detailed_status': 'OK', 'status_code': 0, 'timestamp': 1701381838, 'analysis_time': 9.18665, 'input_process': 'libvorbisfile L+R 44100->22050'}, 'track': {'num_samples': 3643672, 'duration': 165.2459, 'sample_md5': '', 'offset_seconds': 0, 'window_seconds': 0, 'analysis_sample_rate': 22050, 'analysis_channels': 1, 'end_of_fade_in': 0.0, 'start_of_fade_out': 148.25941, 'loudness': -7.678, 'tempo': 121.967, 'tempo_confidence': 0.408, 'time_signature': 4, 'time_signature_confidence': 0.997, 'key': 1, 'key_confidence': 0.827, 'mode': 1, 'mode_confidence': 0.722, 'codestring': 'eJxdmluWIykMRLfiJSRv2P_G5t7ALrvno_sUOB8gQqGQlHuVecru8_W8Tq2jnzHH68xXPWv2ddp41dpf7TmzPuOUV-_7dU5vo_ZSXqvNV69ntz1b4bbnVZ75jPaUhz9rmY5L6fN5zqv0Z7_WfkrdtbcXL-Y1e5zVRxmvsk512E85_nrGZ9gXf5XOKtoz9lP78-L-6nqfWgpLqHNvfu2tr7EOay-VYVssj2Erc79mYfmrbH7obGjy4Get8rzaZEd71eeZvOTVzsOvtc6xfHJ_eNHsvfO0ul69sMW92tP7mBgDM_D4h8eOp77YBxfvxo767C_-PVpntDG8dzMX82AwXsLFbOSpLW97jcYO52a_a_X1GrNl_3uXwTrGetu27TMKP-8xX6ewsto29z2bnbRSDu9sr9nY8WL7LKwf1s-bz668p3Kgc3MurXDjrGu9MALrKiyyVCy9WsVagIKV-Wu_puVAWctrjd3fpu0tp7mFyrPYJmYEJm-sPA1DaZ4vWDabcM3czCZee7ND4cGTMcLrPOMPLn01jpc9TW4a2RPA3Ncg7EGIXvRgrz349Yse4cIz-_7BS2E5_Vpked6AYWqwXjn1uRivv32NXjDHw11fzJRS5y9oSuFIf1BTOLQpTuZa1W2VN4zYO5bFFcQRhuLpLJLx16tY5KvcUxQ67egMVSh9scPJzP0LnlLPqf84V9PbvubirVz2tRdgfv5BUAHQ-_2EsbVZuy43a98HBBaM87Eh5mXcdIjdoAzxVQJyWeG0ungDhsempUz8u3n_8bxx0gfccf3gr9d4NljAXIyDNFyr1jJ4_sCn4mvYCGsUPLCKRGwEwcAXD_dPtnjmHeuM2BBkS2CsivUv6GMtjo2x_jfFBFa_fJOxBtAiq4yPix2vX0Lq10Jg6vnHQlsW2hUUQQQ8cWuH_Sy3LIrwXizUK6e5RN2eI_6wJs_y-ngeoCjYmBXsS1SVlTTP7OiK-GThBDYoPGzR8cN5uKAjynQ31srZsOyLsgfnqJ6F_idfHO4sjEXVgptYmUNvAl6dxwy5Z8WlgDlWbow_DIUBFidYy7P3D8vUcjkK6hsPsYBj-_PJWrxeSE044Rk4NZFDWpo4EAZgp4B-6TXsAwLl_qoXsr-5hifmzznRSfzYjrfcPObZ-0jzDZ55cfy9anTGIojX69W-HwBIz7y3y4-gUAT1sSrY4f1s4rkImxUE1LC7CBqn-jyg-GhP3g5kGb-9kLBStGdfzx-FE7Veesrb6XASLiAK9DfEtjeMtuZ73GEpXtocQw8D92C8Asniyfs7G-f3Iw1xgozZmDSK3XXyOnVBLx17PtMJEYcFNytyx1PEwQWwyCkJjPIg9NuOtq_rAQKD_V4eY44jB1vY81Q2tLQgCAKunl0NW0JxeMzy-ZfweQh7OvJLfJLV1QuxXUQAp8mJwVswAXfx6Abqcn3fH58kjAq-fllpLbzECZ30ktDYhvJ-MTtRGELizL-o0YOeczHHFSUmgw76G3N7FE63Jh4QAYiFvJJA0ELdWLWNxZjD12mbkcLfl0Fdn17wsfB4O2lQb-B8BJm6idcwlrYMJby4-rshUuJnJ4Q51YeCZa_xtOP1Oi2hZh7NyOEU3s8Olzywcljz7ZWn8-aq12KepiDh-ZpI9madJ0HrTWOtT3DhSkJ7HUOs7cok_iYLhQ5a21syNtx3DEZol1QgP57XHEtqwBcGmLpjzIzZh5DleZDzoxNC3yqkFlrXqXAaBRQQj330KglaNgcCcB9h398vpKoShhMHyqwXR0Vdskb0mBDStpxcc-yq3yd-phN65Y9QYL2c6FdYthC7IIPYcesGX7-JvkorbUVR_mkH9sn9XXlyonaW5EFYXcRY3UdCc0ewN9BmrBcOIyoxludtAyFaE-_F7RgrJnBKok6HFfBFvZaIDD8SqHDFo1NsfZCzx5EUAyAIHYgtWmhe3YT34VS4vvoNL2I5a0eTSqtTOmKn_Rn90hJWFNI9xH5pyciNeKu_WoAAPH4N0ItS66ueeiTn1yD9avN6nhmNgDAoGgDfQ9Dw_Hq5BQQbahjrYsCRMA15M9bFtjw74mzSjBBqIgaN3J7-gdDDyrmbDX8hpPCQJfAsj3JGd0e-9Sa1vIQsFxCF4WH-ki0ffYpkZu8bkrUQ0w0jsuMuDwVDVf3ChNR-5RPny1h99WXyPvRVHRAnJ7Rh98itLg8-_i5PESQUMWYCiA-dTpndeNxQShDddOmtbVQSQIjYhGZkXMPLjR2zJ1OHdiMlv1bH8jr0wgxigLFKgnGVyHg9z2WDCCG0A4FFKeb7ikSMi_T11lrqDEJ_j6znxJjICa_E104mp2jg7Msn3xiqFWXfjxbKFZe5a1cGQrRgR7WPWzvDlqLf47cl1u6h8mviutjDkZiAEmJF_cjLOSRWSjjfPk-TGfJbtO7wMXpRVy01xgEdMVrgA8cnopTQB8tWhaa81eEtiJBkZBTFg5wFcx_HEers38SG54e3b6iDARhH8pHX4tjkNhx41RXwEhZBBlYvpiABzmQ60S7t4HWoUMa6JYbksIUQEVo6VHlM_JaEL5DiAZ42hzoE9OUx0lgeGAkPhUGbrJqxoe4MeQUxznjf-AFPwaovISiT8jvHwvUR8B16BXTuIALe_ICFCD9AbDyCXjbLfsmXM0kQtsdtx9AtlWN4lSnpMJE28hG6SGKGO3rLN-XriIAn98dSAIqxPCbCRR_vn09iN_Y1t0iOO-4ETvbIqZfaD5GEY3EcIoM1PEfObCb2kTlyoyteEhtOiU9NYI5psBiLH-RzyA8IDDcEKUUi5_6l3iKKE0mWZ74lMu5HEe3FL9tY2GUAwMzz983jZRkTvqEuuZGAaMr6tm6n3AadTQdOCoPC6O5KivNEThNETcrTzdg_Jha9XGmJZAtwUySwZCxW7pn1gWuzVgKjijBZ_lEO8rhnqcRTUYFbHqBmicMEBtzyVOQBY8l6aAkRBbY9f2kaTmD3ZL6KM3JROAzAztRNjFsoKXVsaJeT7Jp5parAU5dDXVdBpnJBiQ4j9QzLJj2Af5p0cwtAijvCv0q8f0hWD5iyyo-HzMhnHoh-R34wllJuWaO4odRIkqXzUK83Tt2sHeZ9Sfb7A1ivT9bxzh-O43bhVHwxC573OM3iZc0ZtQwLthlXAuc3q3-skbGelEqqUbKYv82wqmyE6EHazauWcWZd0N-VNgg6LLWn4cJADnx1kdZTiLnq-eH8j_l_fathEAensp7-oUzWyF9_chnhXbxDC_5YdN8aHEoWkxOaU9zThLilOS25BSaJ-Ya_zJRVlkm7sYdxSHhyctIgV1pIAbuWtFB3KywMpnAR9ABjcYwHYFtLbyusu5DjeERxvG5 ...

# %%
#Tempo of an individual song.
test['track']['tempo']
# Out:
# 121.967

# %%
#Then go to each song and extract its details.
#Link below has the fields to pull
#https://developer.spotify.com/documentation/web-api/reference/get-audio-analysis
#Doing this with a loop. Eventually put this into a function. And store results into pandas dataframe.
tempo = []
duration = []
loudness = []
tempo_conf = []
barsc = []
beatsc = []
for thing in song:
    track = sp.audio_analysis(thing)
    #Extract desired data.
    tempo.append(track['track']['tempo'])
    duration.append(track['track']['duration'])
    loudness.append(track['track']['loudness'])
    tempo_conf.append(track['track']['tempo_confidence'])
    barsc.append(len(track['bars']))
    beatsc.append(len(track['beats']))

# %%
#Then combine into pandas dataframe. Include sone name too.
import pandas as pd
data = pd.DataFrame({
    'title': song_name,
    'tempo': tempo,
    'dur': duration,
    'loud': loudness,
    'tempc': tempo_conf,
    'bars': barsc,
    'beats': beatsc
})
display(data)
# Out:
#                                                 title    tempo        dur  \
# 0                    Never Lose Me (feat. Lil Yachty)  121.967  165.24590
# 1                            Murder On The Dancefloor  117.320  231.40000
# 2                                              greedy  111.004  131.87206
# 3                                         Lovin on Me  104.983  138.41129
# 4                                                FTCU  144.978  172.13791
# ..                                                ...      ...        ...
# 70                                    Sweater Weather  124.053  240.40000
# 71                                          Escapism.   96.107  272.37332
# 72  Vegas (From the Original Motion Picture Soundt...  159.969  182.90668
# 73                                          As It Was  173.930  167.30318
# 74                                    I Ain't Worried  139.994  148.48586
#
#      loud  tempc  bars  beats
# 0  -7.678  0.408    81    330
# 1  -5.302  0.913   110    444
# 2  -3.190  0.962    59    239
# 3  -4.911  0.776    59    240
# 4  -6.694  0.674   101    411
# ..    ...    ...   ...    ...
# 70 -2.810  0.396   120    482
# 71 -5.355  0.198   111    436
# 72 -7.574  0.303   119    480
# 73 -5.338  0.510   118    474
# 74 -5.927  0.795    83    339
#
# [75 rows x 7 columns]

# %%
#now including into a function
def spottok(creator, playlist_id):
    playlist = sp.user_playlist_tracks(creator,playlist_id)["items"]
    song = []
    song_name = []
    for track in playlist:
        song.append(track["track"]["id"])
        song_name.append(track["track"]["name"])

    tempo = []
    duration = []
    loudness = []
    tempo_conf = []
    barsc = []
    beatsc = []
    for thing in song:
        track = sp.audio_analysis(thing)
        #Extract desired data.
        tempo.append(track['track']['tempo'])
        duration.append(track['track']['duration'])
        loudness.append(track['track']['loudness'])
        tempo_conf.append(track['track']['tempo_confidence'])
        barsc.append(len(track['bars']))
        beatsc.append(len(track['beats']))

    #Then combine into pandas dataframe. Include sone name too.
    import pandas as pd
    data = pd.DataFrame({
        'title': song_name,
        'tempo': tempo,
        'dur': duration,
        'loud': loudness,
        'tempc': tempo_conf,
        'bars': barsc,
        'beats': beatsc
    })
    return data

# %%
dataset = spottok("spotify","6OcWuyMNKus06gmrh4FEiX")

# %%
display(dataset)
# Out:
#                                                 title    tempo        dur  \
# 0                    Never Lose Me (feat. Lil Yachty)  121.967  165.24590
# 1                            Murder On The Dancefloor  117.320  231.40000
# 2                                              greedy  111.004  131.87206
# 3                                         Lovin on Me  104.983  138.41129
# 4                                                FTCU  144.978  172.13791
# ..                                                ...      ...        ...
# 70                                    Sweater Weather  124.053  240.40000
# 71                                          Escapism.   96.107  272.37332
# 72  Vegas (From the Original Motion Picture Soundt...  159.969  182.90668
# 73                                          As It Was  173.930  167.30318
# 74                                    I Ain't Worried  139.994  148.48586
#
#      loud  tempc  bars  beats
# 0  -7.678  0.408    81    330
# 1  -5.302  0.913   110    444
# 2  -3.190  0.962    59    239
# 3  -4.911  0.776    59    240
# 4  -6.694  0.674   101    411
# ..    ...    ...   ...    ...
# 70 -2.810  0.396   120    482
# 71 -5.355  0.198   111    436
# 72 -7.574  0.303   119    480
# 73 -5.338  0.510   118    474
# 74 -5.927  0.795    83    339
#
# [75 rows x 7 columns]

# %%
#Individual song
#https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr

#Get song details

#Get album of song, then those details

#Get artist, details of that.

# %%
#Look at a specific artist. Led.
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

led_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

results = spotify.artist_albums(led_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# The Complete BBC Sessions (Remastered)
# Celebration Day
# Mothership (Remastered)
# How the West Was Won (Remaster)
# Coda (Remaster)
# Coda (Deluxe Edition)
# In Through the out Door (Remaster)
# In Through the out Door (Deluxe Edition)
# The Song Remains the Same (Remaster)
# Presence (Remaster)
# Presence (Deluxe Edition)
# Physical Graffiti (Remaster)
# Physical Graffiti (Deluxe Edition)
# Houses of the Holy (Remaster)
# Houses of the Holy (Deluxe Edition)
# Led Zeppelin IV (Remaster)
# Led Zeppelin IV (Deluxe Edition)
# Led Zeppelin III (Deluxe Edition)
# Led Zeppelin III (Remaster)
# Led Zeppelin II (Remaster)
# Led Zeppelin II (Deluxe Edition)
# Led Zeppelin (Remaster)
# Led Zeppelin (Deluxe Edition)

# %%
#Led top tracks.
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
results = spotify.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Stairway to Heaven - Remaster
# audio    : https://p.scdn.co/mp3-preview/337c8d45ac66899bc2db9ef3ed9438fe1d035ab1?cid=b6f751af0bc449bb9915a16ead60c722
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Immigrant Song - Remaster
# audio    : https://p.scdn.co/mp3-preview/f50f3416ea0807503e172ba87a92d8047d4f95da?cid=b6f751af0bc449bb9915a16ead60c722
# cover art: https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
#
# track    : Whole Lotta Love - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/89f3dc45265602fa874c23d638538af0f2c6b56a?cid=b6f751af0bc449bb9915a16ead60c722
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Black Dog - Remaster
# audio    : https://p.scdn.co/mp3-preview/78dd352fdbe8d2a867b72c5a71ac44ef6a462ab4?cid=b6f751af0bc449bb9915a16ead60c722
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Rock and Roll - Remaster
# audio    : https://p.scdn.co/mp3-preview/9464a064068943a58f673035d9ebe58e98f46bea?cid=b6f751af0bc449bb9915a16ead60c722
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Good Times Bad Times - 1993 Remaster
# audio    : https://p.scdn.co/mp3-preview/499f6278a140080d3218c448448d0eb149eb65b7?cid=b6f751af0bc449bb9915a16ead60c722
# cover art: https://i.scdn.co/image/ab67616d0000b2736f2f499c1df1f210c9b34b32
#
# track    : Ramble On - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/e734d4e4f125ff5fbe7d69faa7d505dc744fb7bb?cid=b6f751af0bc449bb9915a16ead60c722
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Going to California - Remaster
# audio    : https://p.scdn.co/mp3-preview/8c2452c1db9c3a7aad2b826cb52303a689814f6e?cid=b6f751af0bc449bb9915a16ead60c722
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Kashmir - Remaster
# audio    : https://p.scdn.co/mp3-preview/4d9bde799eec8913e53c184c45b9fd575690b917?cid=b6f751af0bc449bb9915a16ead60c722
# cover art: https://i.scdn.co/image/ab67616d0000b273765b0617b572bdd1dbdc7d8e
#
# track    : Over the Hills and Far Away - Remaster
# audio    : https://p.scdn.co/mp3-preview/a828935e429be801aa374eeeb8b2cb0d91755d57?cid=b6f751af0bc449bb9915a16ead60c722
# cover art: https://i.scdn.co/image/ab67616d0000b2731aa47e71c4edfeaddb65cd54

# %%
#Function to extract data.
def call_playlist(creator, playlist_id):

    #step1

    playlist_features_list = ["artist","release","track_name",  "track_id",  "danceability","energy","key","loudness","mode", "speechiness","instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]

    playlist_df = pd.DataFrame(columns = playlist_features_list)

    #step2

    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    for track in playlist:
        # Create empty dict
        playlist_features = {}
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["release"] = track["track"]["album"]["release_date"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]

        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[5:]:
            playlist_features[feature] = audio_features[feature]

        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)

    #Step 3

    return playlist_df

# %%
#Apply function for specific spotify playlist.
call_playlist("spotify","7vI0tN3yUn07dkK9T6p2pg")
# Out:
#             artist     release                                 track_name  \
# 0             Xavi  2023-11-30                                  La Diabla
# 1        Bad Bunny  2023-10-13                                PERRO NEGRO
# 2          KAROL G  2023-08-11                                      QLONA
# 3             Xavi  2023-08-17                                 La Víctima
# 4   iñigo quintero  2022-09-23                                Si No Estás
# ..             ...         ...                                        ...
# 94  Rauw Alejandro  2021-12-10                               Desesperados
# 95         ROSALÍA  2022-03-18                                      CANDY
# 96     Danny Ocean  2022-02-17                          Fuera del mercado
# 97       Tiago PZK  2022-01-05  Entre Nosotros (Remix) [con Nicki Nicole]
# 98            Mora  2021-07-08                            Volando - Remix
#
#                   track_id danceability  energy key  loudness mode  \
# 0   0R6NfOiLzLj4O5VbYSJAjf          NaN   0.819  11    -4.372    0
# 1   7iQXYTyuG13aoeHxGG28Nh          NaN   0.778   5    -2.248    1
# 2   3XB5uhhlYSnkxpSihkNQwh          NaN   0.756   7    -7.409    0
# 3   5XVdHRf4CAJ2Jm0uMIy5qY          NaN   0.835  11    -3.598    0
# 4   2HafqoJbgXdtjwCOvNEF14          NaN   0.421   5    -8.720    1
# ..                     ...          ...     ...  ..       ...  ...
# 94  6mmPpaltUZK7xjNlBPQQ0p          NaN   0.694   1    -3.350    0
# 95  70AYiGbc4mWZGEqiipBBDb          NaN   0.490   4    -5.726    0
# 96  1UdzJEpgJxtuXAlCOvD4S0          NaN   0.673   8    -5.649    1
# 97  4TGwERXRlyQtBdggYTHo6j          NaN   0.438   5    -5.784    0
# 98  0G2zPzWqVjR68iNPmx2TBe          NaN   0.688   6    -4.649    1
#
#     speechiness instrumentalness  liveness  valence    tempo duration_ms  \
# 0        0.0409                0    0.2360    0.697  131.842      172264
# 1        0.2620         0.000022    0.1790    0.345   96.057      162768
# 2        0.3380         0.000002    0.0871    0.421  169.925      172798
# 3        0.0767                0    0.1090    0.666  140.082      156346
# 4        0.0285                0    0.1380    0.524   98.224      184061
# ..          ...              ...       ...      ...      ...         ...
# 94       0.0783          0.00125    0.0878    0.511   90.020      224997
# 95       0.2260           0.0116    0.1560    0.403  179.905      193480
# 96       0.1440                0    0.1310    0.266   92.060      159849
# 97       0.0433                0    0.3730    0.605  170.106      260000
# 98       0.0673                0    0.1130    0.632  153.979      273474
#
#    time_signature
# 0               3
# 1               4
# 2               4
# 3               4
# 4               4
# ..            ...
# 94              4
# 95              4
# 96              4
# 97              3
# 98              4
#
# [99 rows x 16 columns]

# %%
#Sources
#https://www.linkedin.com/pulse/extracting-your-fav-playlist-info-spotifys-api-samantha-jones
